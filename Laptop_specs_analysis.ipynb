# %% [markdown]
# ## LAPTOP SPECS ANALYSIS

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df= pd.read_csv("E:\\2-Laptop Specs Analysis\\2-Laptop Specs Analysis\\LAPTOP SPECS.csv")

# %%
df.head()
# Out:
#                                                 name  price_eur  display_inch  \
# 0             Apple MacBook Air M1 256GB, Space grau     912.99          13.0
# 1  MSI Stealth 17 Studio A13VI013  Intel Core i9 ...    4680.23          17.3
# 2  MSI Summit E14 FlipEvo A12MT049 i71260P/16GB/1...    1651.12          14.0
# 3    Gigabyte GBT AORUS 15 9KFE3DE383SH i5 W11 144Hz    1087.38          15.6
# 4  Fujitsu Lifebook A3511 FHD i31115G4 8GB 256GBS...     354.97          15.6
#
#   display_cm display_resolution display_ratio weight_kg height_mm width_mm  \
# 0       33.8          2560x1600         16:09      1.29      16.1    304.1
# 1       43.9          3840x2160         16:09       2.8      20.1    397.6
# 2       35.6          2880x1800             -       1.6      17.9      314
# 3          -                  -             -         -         -        -
# 4       39.6          1920x1080             -      1.95      23.9      361
#
#   depth_mm  ... keyboard_backlit keyboard_numpad has_webcam has_bluetooth  \
# 0    212.4  ...             True           False       True          True
# 1    283.5  ...             True            True       True          True
# 2    227.5  ...             True           False       True          True
# 3        -  ...            False           False      False         False
# 4      244  ...            False            True       True          True
#
#   bluetooth_version       wifi_standard product_ean            product_sku  \
# 0                 5   WiFi 6 (802.11ax)    1.94E+11               MGN63D/A
# 1               5.3  WiFi 6E (802.11ax)    4.71E+12              0017P2013
# 2               5.2  WiFi 6E (802.11ax)    4.72E+12              0014F1049
# 3                 -                   -    4.72E+12  AORUS 15 9KFE3DE383SH
# 4               5.1  WiFi 6E (802.11ax)    4.07E+12             FPC04902BS
#
#   release_year   category
# 0         2020  Notebooks
# 1            -  Notebooks
# 2            -  Notebooks
# 3            -  Notebooks
# 4            -  Notebooks
#
# [5 rows x 33 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 764 entries, 0 to 763
# Data columns (total 33 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   name                 764 non-null    object
#  1   price_eur            764 non-null    float64
#  2   display_inch         763 non-null    float64
#  3   display_cm           764 non-null    object
#  4   display_resolution   764 non-null    object
#  5   display_ratio        764 non-null    object
#  6   weight_kg            764 non-null    object
#  7   height_mm            764 non-null    object
#  8   width_mm             764 non-null    object
#  9   depth_mm             764 non-null    object
#  10  operating_system     764 non-null    object
#  11  cpu_processor        764 non-null    object
#  12  ram_memory           764 non-null    object
#  13  gpu_integrated       764 non-null    object
#  14  gpu_extra            763 non-null    object
#  15  internal_storage_gb  764 non-null    object
#  16  storage_type         764 non-null    object
#  17  battery_life_h       763 non-null    object
#  18  battery_capacity_wh  764 non-null    object
#  19  psu_watts            764 non-null    object
#  20  audio_system         763 non-null    object
#  21  speakers_count       764 non-null    object
#  22  has_touchscreen      764 non-null    bool
#  23  keyboard_backlit     764 non-null    bool
#  24  keyboard_numpad      764 non-null    bool
#  25  has_webcam           764 non-null    bool
#  26  has_bluetooth        764 non-null    bool
#  27  bluetooth_version    764 non-null    object
#  28  wifi_standard        764 non-null    object
#  29  product_ean          764 non-null    object
#  30  product_sku          764 non-null    object
#  31  release_year         763 non-null    object
#  32  category             764 non-null    object
# dtypes: bool(5), float64(2), object(26)
# memory usage: 171.0+ KB

# %%
df.columns
# Out:
# Index(['name', 'price_eur', 'display_inch', 'display_cm', 'display_resolution',
#        'display_ratio', 'weight_kg', 'height_mm', 'width_mm', 'depth_mm',
#        'operating_system', 'cpu_processor', 'ram_memory', 'gpu_integrated',
#        'gpu_extra', 'internal_storage_gb', 'storage_type', 'battery_life_h',
#        'battery_capacity_wh', 'psu_watts', 'audio_system', 'speakers_count',
#        'has_touchscreen', 'keyboard_backlit', 'keyboard_numpad', 'has_webcam',
#        'has_bluetooth', 'bluetooth_version', 'wifi_standard', 'product_ean',
#        'product_sku', 'release_year', 'category'],
#       dtype='object')

# %%
df_copy= df.copy()

# %%
laptops = df_copy[['name', 'price_eur', 'display_inch', 'display_resolution',
         'weight_kg','operating_system', 'cpu_processor', 
        'ram_memory', 'gpu_integrated','internal_storage_gb', 'storage_type',
         'battery_capacity_wh', 'has_webcam','has_bluetooth', 'wifi_standard']]

# %% [markdown]
# ## DATA CLEANING

# %%
laptops.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 764 entries, 0 to 763
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   name                 764 non-null    object
#  1   price_eur            764 non-null    float64
#  2   display_inch         763 non-null    float64
#  3   display_resolution   764 non-null    object
#  4   weight_kg            764 non-null    object
#  5   operating_system     764 non-null    object
#  6   cpu_processor        764 non-null    object
#  7   ram_memory           764 non-null    object
#  8   gpu_integrated       764 non-null    object
#  9   internal_storage_gb  764 non-null    object
#  10  storage_type         764 non-null    object
#  11  battery_capacity_wh  764 non-null    object
#  12  has_webcam           764 non-null    bool
#  13  has_bluetooth        764 non-null    bool
#  14  wifi_standard        764 non-null    object
# dtypes: bool(2), float64(2), object(11)
# memory usage: 79.2+ KB

# %%
laptops[laptops['display_inch'].isnull()]
# Out:
#                                              name  price_eur  display_inch  \
# 754  Notebook Apple Macbook Pro 14 M2 PRO 10C/16C    3243.67           NaN
#
#     display_resolution weight_kg operating_system cpu_processor ram_memory  \
# 754                  -         -                -             -          -
#
#     gpu_integrated internal_storage_gb storage_type battery_capacity_wh  \
# 754              -                   -            -                   -
#
#      has_webcam  has_bluetooth wifi_standard
# 754       False          False             -

# %%
laptops= laptops.drop(754)

# %%
null_display= laptops[laptops['display_resolution'].isnull()]

# %%
index_list= null_display.index.tolist()

# %%
laptops = laptops.drop(index_list)

# %%
laptops= laptops.reset_index(drop= True)

# %% [markdown]
# ## CHECK DUPLICATE ROWS

# %%
duplicate_rows= laptops[laptops.duplicated(['name'])]

# %%
#drop row 226 because it is duplicate:
laptops = laptops.drop(226)

# %%
laptops = laptops.drop(226)

# %%
laptops = laptops.reset_index(drop=True)

# %%
laptops.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 758 entries, 0 to 757
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   name                 758 non-null    object
#  1   price_eur            758 non-null    float64
#  2   display_inch         758 non-null    float64
#  3   display_resolution   758 non-null    object
#  4   weight_kg            758 non-null    object
#  5   operating_system     758 non-null    object
#  6   cpu_processor        758 non-null    object
#  7   ram_memory           758 non-null    object
#  8   gpu_integrated       758 non-null    object
#  9   internal_storage_gb  758 non-null    object
#  10  storage_type         758 non-null    object
#  11  battery_capacity_wh  758 non-null    object
#  12  has_webcam           758 non-null    bool
#  13  has_bluetooth        758 non-null    bool
#  14  wifi_standard        758 non-null    object
# dtypes: bool(2), float64(2), object(11)
# memory usage: 78.6+ KB

# %%
laptops[laptops['wifi_standard'].isnull()]
# Out:
# Empty DataFrame
# Columns: [name, price_eur, display_inch, display_resolution, weight_kg, operating_system, cpu_processor, ram_memory, gpu_integrated, internal_storage_gb, storage_type, battery_capacity_wh, has_webcam, has_bluetooth, wifi_standard]
# Index: []

# %%
laptops.iloc[413,7] = 8.0
laptops.iloc[413,8] = 'Andreno 618 Graphics'
laptops.iloc[413,11] = 46.7

# %%
laptops.iloc[142,4] = 2.08
laptops.iloc[142,11] = 60.0
laptops.iloc[149,4] = 1.18
laptops.iloc[194,4] = 0.88
laptops.iloc[212,4] = 0.99
laptops.iloc[225,4] = 0.99
laptops.iloc[265,4] = 1.13
laptops.iloc[337,4] = 1.37
laptops.iloc[412,4] = 1.19
laptops.iloc[459,4] = 1.19
laptops.iloc[463,4] = 1.19
laptops.iloc[596,4] = 2.08
laptops = laptops.drop(599)

# %%
laptops.iloc[3,5] = 'windows 10 pro'
laptops.iloc[165,5] = 'MacOS'

# %%
laptops.dropna(inplace=True)

# %%
laptops = laptops.reset_index(drop=True)

# %%
laptops.describe()
# Out:
#          price_eur  display_inch
# count   757.000000     757.00000
# mean   1729.339207      14.42074
# std     997.361156       2.10808
# min     276.800000       0.00000
# 25%    1032.670000      14.00000
# 50%    1521.100000      14.00000
# 75%    2100.130000      15.60000
# max    6130.110000      17.30000

# %%
laptops.iloc[52,4] = 0.91
laptops.iloc[190,4] = 0.89
laptops.iloc[279,4] = 0.97
laptops.iloc[290,4] = 0.91

# %%
# update the crt RAM
laptops.iloc[378,7] = 64

# %%
df.to_csv('cleansed_data.csv',index=False)

# %% [markdown]
# ## EDA AND SYAYISTICS BASED ANALYSIS

# %% [markdown]
# #### Top 10 expensive laptops

# %%
top_10 = laptops.nlargest(10,columns=['price_eur'])
top_10.plot(kind='bar', x='name', y='price_eur', title='10 most expenses laptops', color='orange');

# %% [markdown]
# #### 10 least expensive laptops

# %%
least_10 = laptops.nsmallest(10,columns=['price_eur'])
least_10.plot.bar(x='name',y='price_eur',title='10 Least Expensive Laptops', color='green');

# %% [markdown]
# #### Largest screen size

# %%
max_display = laptops['display_inch'].max()
laptops[laptops['display_inch'] == max_display]
# Out:
#                                                   name  price_eur  \
# 1    MSI Stealth 17 Studio A13VI013  Intel Core i9 ...    4680.23
# 18             LG GRAM 17Z90QG.AP78G i7 W11P FHD black    1266.53
# 139  MSI CreatorPro Z17 HX A13VKT219 i913980HX/RTX3...    5024.99
# 142                   Terra Mobile 1716T i31115G4 W11P     789.00
# 159       Gigabyte AORUS 17H BXF74DE554SH i7 W11 360Hz    2968.73
# 167   Gigabyte GBT AORUS 17X AZFD5DE665SH i9 W11 240Hz    4650.95
# 212                     Terra MOBILE 1716U i51235U W11     799.00
# 213  MSI Pulse 17 B13VGK068  Intel Core i7 13700H /...    2409.90
# 215  Gigabyte AORUS 17X AXFD4DE694SH 17,3 i9 W11 240Hz    3489.99
# 242       MSI Raider GE78 HX 13VG (RTX 4070, GDDR6 8GB    3671.47
# 269  MSI Titan GT77HX 13VH045  Intel Core i9 13980H...    4935.13
# 293        Terra MOBILE GAMER ELITE 5v2 i913900HX W11P    2599.00
# 347          MSI Stealth 17 A13VF (RTX 4060, GDDR6 8GB    2946.08
# 369  MSI Stealth 16 Studio A13VF075  Intel Core i7 ...    2960.98
# 385  MSI CreatorPro Z17 HX A13VJT221 i913980HX/RTX2...    4277.99
# 391  Lenovo V17 G4 IRU i U300/8GB/256SSD/FHD/matt/noOS     434.99
# 485  LENOVO V17 G3 Intel Core i51235U FHD 16GB 512G...     915.68
# 502  ACER Aspire 5 A51753G742E W11P i71255U/16GB/1T...    1218.25
# 515  Notebook 17.3" Acer Aspire 5 A5175358RH W11P i...     824.73
# 546  Acer Aspire 5 A51752 Core i5 1135G7  8 GB RAM ...     706.50
# 654                          ACER AN5175596S6 I912900H    1548.99
# 686  Lenovo V17 G4 Intel Core i51335U No Touch FHD ...     785.22
# 696  Lenovo V17 G4 Intel Core i51335U FHD 16GB 512G...     847.59
# 706  Acer Aspire 5 A51753 Core i7 1255U  16 GB RAM ...    1138.28
# 713  MSI Stealth 17 Studio A13VH014  Intel Core i9 ...    4899.28
# 719        TERRA MOBILE 1778R i713700H W11P (1920x1080    1669.00
# 720                                 Terra MOBILE 1716A     649.00
#
#      display_inch display_resolution weight_kg operating_system cpu_processor  \
# 1            17.3          3840x2160       2.8  Windows 11 Home      i913900H
# 18           17.3          2560x1600      1.35   Windows 11 Pro       i71260P
# 139          17.3                  -         -                -             -
# 142          17.3          1920x1080      2.08   Windows 11 Pro      i31115G4
# 159          17.3                  -         -                -             -
# 167          17.3                  -         -                -             -
# 212          17.3          1920x1080      0.99  Windows 11 Home       i51235U
# 213          17.3          1920x1080       2.7  Windows 11 Home      i713700H
# 215          17.3          2560x1440       2.8  Windows 11 Home     i913980HX
# 242          17.3          2560x1600       3.1  Windows 11 Home   Intel HM770
# 269          17.3          3840x2160       3.3  Windows 11 Home   Intel HM770
# 293          17.3          2560x1440       2.8   Windows 11 Pro     i913900HX
# 347          17.3          2560x1440       2.8  Windows 11 Home      i713700H
# 369          17.3          2560x1600      1.99  Windows 11 Home      i713700H
# 385          17.3                  -         -                -             -
# 391          17.3                  -         -                -             -
# 485          17.3          1920x1080       2.2   Windows 11 Pro     Intel SoC
# 502          17.3                  -         -                -             -
# 515          17.3                  -         -                -             -
# 546          17.3          1920x1080       2.3            Linux     Intel SoC
# 654          17.3                  -         -                -             -
# 686          17.3          1920x1080      2.02   Windows 11 Pro     Intel SoC
# 696          17.3          1920x1080      2.02   Windows 11 Pro     Intel SoC
# 706          17.3          1920x1080       2.3   Windows 11 Pro     Intel SoC
# 713          17.3          3840x2160       2.8  Windows 11 Home      i913900H
# 719          17.3          1920x1080       2.5   Windows 11 Pro      i713700H
# 720          17.3          1920x1080       2.4   Windows 11 Pro        G6405U
#
#     ram_memory          gpu_integrated internal_storage_gb storage_type  \
# 1           64  Intel Iris Xe Graphics                   4          SSD
# 18          16  Intel Iris Xe Graphics                1000          SSD
# 139          -                       -                   -            -
# 142          8     Intel® UHD Graphics                 500          SSD
# 159          -                       -                   -            -
# 167          -                       -                   -            -
# 212          8  Intel Iris Xe Graphics                 500          SSD
# 213         16  Intel Iris Xe Graphics                   1          SSD
# 215         16     Intel® UHD Graphics                1000          SSD
# 242         32     Intel® UHD Graphics                   2          SSD
# 269         64     Intel® UHD Graphics                   2          SSD
# 293         32     Intel® UHD Graphics                   2          SSD
# 347         16  Intel Iris Xe Graphics                   2          SSD
# 369         16  Intel Iris Xe Graphics                   2          SSD
# 385          -                       -                   -            -
# 391          -                       -                   -            -
# 485         16     Intel® UHD Graphics                 512          SSD
# 502          -                       -                   -            -
# 515          -                       -                   -            -
# 546          8  Intel Iris Xe Graphics                 256          SSD
# 654          -                       -                   -            -
# 686          8  Intel Iris Xe Graphics                 256          SSD
# 696         16  Intel Iris Xe Graphics                 512          SSD
# 706         16  Intel Iris Xe Graphics                   1          SSD
# 713         64  Intel Iris Xe Graphics                   2          SSD
# 719         16  Intel Iris Xe Graphics                   1          SSD
# 720          8     Intel® UHD Graphics                 256          SSD
#
#     battery_capacity_wh  has_webcam  has_bluetooth       wifi_standard
# 1                    99        True           True  WiFi 6E (802.11ax)
# 18                   80        True           True  WiFi 6E (802.11ax)
# 139                   -       False          False                   -
# 142                60.0        True           True   WiFi 6 (802.11ax)
# 159                   -       False          False                   -
# 167                   -       False          False                   -
# 212                   -        True           True   WiFi 6 (802.11ax)
# 213                  90        True           True   WiFi 6 (802.11ax)
# 215                  99        True           True  WiFi 6E (802.11ax)
# 242                  99        True           True  WiFi 6E (802.11ax)
# 269                  99        True           True  WiFi 6E (802.11ax)
# 293                   -        True           True   WiFi 6 (802.11ax)
# 347                  99        True           True  WiFi 6E (802.11ax)
# 369                99.9        True           True  WiFi 6E (802.11ax)
# 385                   -       False          False                   -
# 391                   -       False          False                   -
# 485                  45        True           True   WiFi 6 (802.11ax)
# 502                   -       False          False                   -
# 515                   -       False          False                   -
# 546                  50        True           True  WiFi 6E (802.11ax)
# 654                   -       False          False                   -
# 686                  45        True           True   WiFi 6 (802.11ax)
# 696                  45        True           True   WiFi 6 (802.11ax)
# 706                  50        True           True  WiFi 6E (802.11ax)
# 713                  99        True           True  WiFi 6E (802.11ax)
# 719                   -        True           True   WiFi 6 (802.11ax)
# 720                   -        True           True   WiFi 5 (802.11ac)

# %% [markdown]
# #### Unique relationship between columns

# %%
numerical_columns = laptops.select_dtypes(include='number')
plt.figure(figsize=[10,6])
sns.heatmap(numerical_columns.corr(),annot=True);

# %% [markdown]
# #### Storage type predominant

# %%
laptops['storage_type'].value_counts().plot.bar();

# %% [markdown]
# #### Percentage of laptops have bluetooth and webcam

# %%
with_bluetooth_webcam = laptops[(laptops['has_bluetooth'] == True) & (laptops['has_webcam'] ==True)]
total_laptops = laptops.shape[0]
(with_bluetooth_webcam.shape[0]/total_laptops)*100
# Out:
# 79.52443857331572

# %% [markdown]
# #### Percentage of laptops have webcam but no bluetooth

# %%
no_bluetooth_with_webcam = laptops[(laptops['has_bluetooth'] == False) & (laptops['has_webcam'] == True)]
total_laptops = laptops.shape[0]
(no_bluetooth_with_webcam.shape[0]/total_laptops)*100
# Out:
# 0.0

# %% [markdown]
# #### Percentage of laptops are apple products

# %%
apple_products = laptops[laptops['operating_system'].str.contains('mac',case=False)]
(apple_products.shape[0]/laptops.shape[0])*100
# Out:
# 7.793923381770146

# %%
laptops['operating_system'].value_counts().plot.bar();
